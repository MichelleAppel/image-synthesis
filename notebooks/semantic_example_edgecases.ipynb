# %%
import torch
from torchvision.utils import make_grid

from synthesis_dataset import SynthesisDataset

torch.manual_seed(42)

# %%
synthesis_dataset = SynthesisDataset("..\..\simulation-synthesis\output\MLDataset_256", extension='.png')

# %%
item = synthesis_dataset.__getitem__(9)
print(synthesis_dataset.modalities)
synthesis_dataset.show_imgdir(item)
# Out:
# ['img', 'indexid', 'normals', 'outlines']
# <PIL.Image.Image image mode=RGB size=1034x260 at 0x223F09C50A0>

# %%
synthesis_dataset.toPilImage(item['indexid'])
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x223F088B8E0>

# %%
intid = torch.floor(item['indexid']*1000).int()

imgs = []
for unique in intid.unique():
    imgs += [1-(intid==unique)*1.0]
    
synthesis_dataset.toPilImage(make_grid(torch.stack(imgs), nrow=4, padding=5))
# Out:
# <PIL.Image.Image image mode=RGB size=1049x1571 at 0x223F0A67F40>
